# %%
class Student:
    def accept(self):
        self.roll = int(input("Enter roll number: "))
        self.name = input("Enter name: ")

        self.subjects = int(input("Enter number of subjects: "))
        self.marks = []

        for i in range(self.subjects):
            mark = int(input("Enter marks: "))
            self.marks.append(mark)

    def display(self):
        print("\nStudent Details")
        print("Roll Number:", self.roll)
        print("Name:", self.name)
        print("Marks:", self.marks)

        total = sum(self.marks)
        average = total / len(self.marks)

        print("Total Marks:", total)
        print("Average:", average)

    def grade(self):
        average = sum(self.marks) / len(self.marks)

        if average >= 90:
            print("Grade: A")
        elif average >= 75:
            print("Grade: B")
        elif average >= 60:
            print("Grade: C")
        elif average >= 40:
            print("Grade: D")
        else:
            print("Grade: F")


s = Student()

s.accept()
s.display()
s.grade()
# Out:
# Enter roll number:  90
# Enter name:  Vaibhav
# Enter number of subjects:  3
# Enter marks:  45
# Enter marks:  80
# Enter marks:  92
# Student Details
# Roll Number: 90
# Name: Vaibhav
# Marks: [45, 80, 92]
# Total Marks: 217
# Average: 72.33333333333333
# Grade: C
