# %%
import pandas as pd 
student = { 
    "name" : ["Vaibhav" , "Sainath" , "John"],
    "Age" : [22,22,28],
    "Marks" : [99,85,59],}
df = pd.DataFrame(student)
print(df)
# Out:
#       name  Age  Marks
# 0  Vaibhav   22     99
# 1  Sainath   22     85
# 2     John   28     59

# %%
data = {
    "Quantity" : [2 , 3, 5],
    "Price" : [100, 200, 300]
}
df = pd.DataFrame(data)
print(df)
df["Total Price"] = df["Quantity"] * df["Price"]
# Out:
#    Quantity  Price
# 0         2    100
# 1         3    200
# 2         5    300
# 0     200
# 1     600
# 2    1500
# Name: Total Price, dtype: int64

# %%
df = pd.DataFrame({"Salary" : [25000, 30000, 35000, 45000]})

df["Normalized"] = (df["Salary"] - df["Salary"].min()) / (df["Salary"].max() -  df["Salary"].min())


print(df)
# Out:
#    Salary  Normalized
# 0   25000        0.00
# 1   30000        0.25
# 2   35000        0.50
# 3   45000        1.00

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
gender = ["male", "female", "male"]
print(le.fit_transform(gender))
# Out:
# [1 0 1]

# %%
df= pd.DataFrame({ "Date" : ["2026-08-15"] })

df["Date"] = pd.to_datetime(df["Date"])

df["Day"] = df["Date"].dt.day
df["Month"] = df["Date"].dt.month
df["Year"] = df["Date"].dt.year

print(df)
# Out:
#         Date  Day  Month  Year
# 0 2026-08-15   15      8  2026

# %%
data = {
    'Customer_ID': ['C101', 'C102', 'C103', 'C104', 'C105',
                    'C106', 'C106', 'C107', 'C108', 'C109'],

    'Age': [25, 30, 22, 35, 29, 25, 25, 40, 28, 32],

    'Gender': ['Male', 'Female', 'Female', 'Male', 'Male',
               'Female', 'Female', 'Male', 'Female', 'Male'],

    'City': ['Pune', 'Mumbai', 'Pune', 'Delhi', 'Mumbai',
             'Pune', 'Pune', 'Delhi', 'Mumbai', 'Pune']
}
